# %% [markdown]
# # **Introduction to Image Processing**
#
# In this tutorial, you will learn some image processing techniques, from basic concepts to classical computer vision and AI methods.
#
# We will use real images collected by our environmental scientists for demonstration.
#
#
# ## What You Will Learn
#
# This tutorial is organized into three parts:
#
# ### 1. Build Image Understanding
#
# * What is an image
# * How pixel values represent information
#
#
# ### 2. Classical Computer Vision
#
# * Segment objects from images
# * Detect object boundaries
# * Measure properties (area, axes)
#
#
# ### 3. AI-Based Methods
#
# * Use YOLO for object detection and segmentation
# * Retrain models using your own dataset
# * Build image classification models (CNN, Random Forest)
# * Apply data augmentation and compare model performance

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please set the working directory to /content/drive/MyDrive/Workshop-Intro-Image-Processing"

# %% [markdown]
# ## Section 1: Image Basics
#
# ### What You Will Do
#
# * Create simple images using NumPy
# * Modify pixel values
# * Display images
# * Explore grayscale and RGB
#
# ### Key Idea
#
# An image is just numbers:
#
# * Grayscale → 2D array
# * RGB → 3D array

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please write Python code to create a 10×10 numpy array filled with zeros to represent a black image. Then, please display it using matplotlib."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please modify the array to draw a square centered in the image with a side length of 6 pixels by setting the selected pixels to 255 (white). Then, please display the result and print the array."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please modify the array to draw a square centered in the image with a side length of 6 pixels by setting the selected pixels to 255 (white). Then, please display the result and print the array."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please modify the image so that the middle square has a gradient intensity instead of a constant color. Then, please display the result.”

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please modify the square so that its inside color is red. Then, please display the image and print only the array shape.”

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please print each RGB channel array separately.”

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please set the inside square to have the following RGB values:Red = 10, Green = 90, Blue = 180. Then, please display the image.

# %% [markdown]
# ## Section 2: From Image to Measurement
#
# We now apply image processing to a real problem: measuring oyster size (area, axes) from images.
#
#
# ### What You Will Do
#
# * Load a real oyster image
# * Analyze RGB channels and intensity
# * Create a mask to segment the oyster
# * Detect the object boundary
# * Measure area and axes
#
#
# ### Key Idea
#
# We convert an image into quantitative data:
#
# Image → Mask → Object → Measurement

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please load the image "Oyster_Images/oyster#6.jpg" and name it oyster_6. Then, please separate the RGB channels and display them in grayscale."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please draw a blue horizontal line across the middle of the image from left to right. Then, please extract the intensity values along this line and plot them clearly. Also, please display the original image with the line drawn on it."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please create a mask where the red channel values are greater than 40. Then, please display: the original image, the mask, and the mask overlaid on the original image with half transparency."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please use cv2.findContours to measure the area and find the object boundaries. Then, please use connected component analysis to detect the object and draw a bounding box around it. Please provide the object statistics, and display the original image with the boundaries and bounding box overlaid, separately."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please fit an ellipse to the object and find the long axis and short axis. Then, please draw the object boundary and both axes on the original image. Please also display the lengths of all axes."

# %% [markdown]
# ## Section 3: Limitations of Classical Methods
#
# Classical methods work well, but can become challenging when conditions are complex.
#
# ### What You Will Do
#
# * Observe segmentation results on another oyster image
# * Identify cases where thresholding does not work well
# * Understand common challenges (background, lighting, etc.)
#
# ### Key Idea
#
# Classical methods rely on simple rules.
# When images become complex...

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please write Python code to load the image "Oyster_Images/oyster#10.jpg" and name it oyster_10. Then, please separate the RGB channels and display them in grayscale.

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please draw a blue vertical line from the top middle to the bottom middle of the image Then, please extract the intensity values along this line and plot them clearly Also, please display the original image with the line drawn on it."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please create a mask where the red channel values are greater than 50. Then, please display the original image, the mask, and the mask overlaid on the original image with half transparency."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please load the image "Oyster_Images/oyster_test.jpg, and name it oyster_test. Then, please separate the RGB channels and display them in grayscale."

# %% [markdown]
# ## Section 4: Object Detection and Segmentation with YOLO
#
# To handle complex images, we can use deep learning models pretrained by other researchers.
#
# However, pretrained models may not work well for our oyster images.
#
# ### What You Will Do
#
# * Run YOLO inference on oyster images
# * Evaluate detection and segmentation results
# * Retrain YOLO using your own dataset
# * Compare results before and after retraining
#
# ### Key Idea
#
# Deep learning models learn from data.
#
# When the data is different, retraining with your own dataset can significantly improve performance.

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please install YOLO."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please use YOLOv8n-seg to perform inference on the oyster_test dataset. Please display the class, bounding boxes, segmentation masks, and confidence scores."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please use YOLOv8m-seg to perform inference on the oyster_test dataset. Please display the class, bounding boxes, segmentation masks, and confidence scores."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please display the folder structure of Oyster_Training_Dataset."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please display the same sample "con1_2N1.jpg" from the train image, mask, and label under the Oyster_Training_Dataset folder.

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please display the contents of the oyster.yaml file."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT: "Please retrain YOLOv8n-seg using the Oyster_Training_Dataset/oyster.yaml file for 50 epochs.
# ####<font color="#F67"> **!!!NOTE!!!:** This step takes a long time (~40 minutes). You can start the cell just to see how the retraining process works, but please stop it early and move on to the next cell, where to load a pretrained model. You can come back and run this full step later when you have more time. Thank you!!"

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please load the retrained YOLO model from /Pretrained/best.pt and assign it to the variable model.

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please use the trained model to perform inference on oyster_test.jpg."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:"Please display the segmented oyster shell mask from the retrained model in one image."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:"Please apply contour detection, connected component analysis, and ellipse fitting. Please count and display the number of oyster shells. Draw the object boundaries and the long and short axes on the image. Label each oyster with an index number, and display the statistics for each oyster shell in order."

# %% [markdown]
# ## Section 5: Image Classification and Data Considerations
#
# In addition to detection, we can classify images into different categories. We will demonstrate this using IFCB data.
#
# ### What You Will Do
#
# * Prepare datasets for classification
# * Train a CNN model on image data
# * Apply data augmentation (rotation, blurring) for imbalanced data
# * Train a Random Forest model using extracted features
# * Compare model performance
#
# ### Key Idea
#
# Model performance depends on both data and method. Random Forest is robust for small datasets. Data augmentation also helps improve performance, especially for imbalanced datasets.

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please check how many images are in each subfolder under folder /IFCB_Dataset."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Load images under akashiwo folder to akashiwo, images under Gyrodinium_sp to Gyrodinium_sp"

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please display 20 images for each class."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please plot a scatter plot showing the image size distribution for each class."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please resize the images to 128×128 Then, please display 20 images for each class, showing both the original and the resized versions."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please create a folder named IFCB_Dataset_A. Then, split the dataset into train, validation, and test sets with ratios of 70%, 15%, and 15% for both class.

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please train a simple 2-layer CNN model on the grayscale images, name the model model_A. Use 64 neurons in each layer. Train the model for 10 epochs with a batch size of 32 and a learning rate of 0.001. Then, please plot the training and validation loss."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please perform predictions on the test_images with the model_A. Then, please display the F1 score, recall, and other evaluation metrics, and plot the confusion matrix."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please copy IFCB_Dataset_A to IFCB_Dataset_B. Then, in IFCB_Dataset_B, keep only 5 training images for the akashiwo class."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please train a simple 2-layer CNN model on the grayscale images, name the model model_B. Use 64 neurons in each layer. Train the model for 10 epochs with a batch size of 32 and a learning rate of 0.001. Then, please plot the training and validation loss."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please perform predictions on the test images under IFCB_Dataset_B with the model_B. Then, please display the F1 score, recall, and other evaluation metrics, and plot the confusion matrix."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please copy IFCB_Dataset_B to IFCB_Dataset_C. Then, in IFCB_Dataset_C, for the akashiwo class, perform data augmentation to increase the number of images to 70 using rotation and blurring."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please train a simple 2-layer CNN model on the grayscale images from IFCB_Dataset_C, name the model model_C. Use 64 neurons in each layer. Train the model for 10 epochs with a batch size of 32 and a learning rate of 0.001. Then, please plot the training and validation loss."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please perform predictions on the test images under IFCB_Dataset_C with the model_C. Then, please display the F1 score, recall, and other evaluation metrics, and plot the confusion matrix.

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please calculate and display the distribution of statistical features (min, max, mean, median, std) for grayscale images in IFCB_Dataset across different classes. Please visualize the distributions using histograms."

# %% [markdown]
# ####<font color="#FF69B4">PROMPT:" Please train separate Random Forest models on IFCB_Dataset_A, IFCB_Dataset_B, and IFCB_Dataset_C using statistical features. Use 100 trees for each model. Then, please evaluate the performance of each model and plot the feature importance.

# %% [markdown]
# ### <font color="#F67">**Congratulations! You’ve successfully completed the Introduction to Image Processing module. Great job—keep building on what you’ve learned!**</font>
